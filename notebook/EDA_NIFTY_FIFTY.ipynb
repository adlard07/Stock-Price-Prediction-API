# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
data = pd.read_csv('data/NSEI.csv', encoding='UTF-8')
data['Date'] = pd.to_datetime(data['Date'], errors='coerce')
data.head()
# Out:
#         Date          Open          High           Low         Close  \
# 0 2022-07-14  16018.849609  16070.849609  15858.200195  15938.650391
# 1 2022-07-15  16010.799805  16066.950195  15927.299805  16049.200195
# 2 2022-07-18  16151.400391  16287.950195  16142.200195  16278.500000
# 3 2022-07-19  16187.049805  16359.500000  16187.049805  16340.549805
# 4 2022-07-20  16562.800781  16588.000000  16490.949219  16520.849609
#
#       Adj Close  Volume
# 0  15938.650391  228600
# 1  16049.200195  205800
# 2  16278.500000  227700
# 3  16340.549805  222600
# 4  16520.849609  284400

# %%
data.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count    248.000000    248.000000    248.000000    248.000000    248.000000
# mean   17912.414748  17984.617699  17817.903809  17905.921591  17905.921591
# std      654.977212    644.299809    664.009937    653.767126    653.767126
# min    16010.799805  16066.950195  15858.200195  15938.650391  15938.650391
# 25%    17518.825196  17625.075683  17426.224610  17533.774902  17533.774902
# 50%    17893.724609  17974.274414  17796.725586  17884.674805  17884.674805
# 75%    18325.424317  18395.812011  18248.287598  18314.875488  18314.875488
# max    19497.449219  19595.349609  19433.500000  19564.500000  19564.500000
#
#               Volume
# count     248.000000
# mean   260758.467742
# std     74930.897240
# min         0.000000
# 25%    220725.000000
# 50%    250450.000000
# 75%    283500.000000
# max    696500.000000

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='Date', y='Close', data=data)
plt.scatter(data['Date'], data['Close'], marker='.')
plt.title('Closing Stock Price Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Stock Price')
plt.show()

# %%
data['Year'] = data['Date'].dt.year
sns.boxplot(x='Year', y='Close', data=data)
plt.title('Closing Stock Prices by Year')
plt.xlabel('Year')
plt.ylabel('Closing Stock Price')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['Close'], kde=True)
plt.title('Distribution of Closing Stock Price')
plt.xlabel('Closing Stock Price')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.histplot(data['Close'].pct_change().dropna(), bins=100, kde=True)
plt.title('S&P 500 Daily Returns')
plt.xlabel('Daily Return')
plt.ylabel('Frequency')
plt.show()
